# %% [markdown]
# # Extracting data from scientific articles (xmls) and disambiguating authors by grouping
#
# ## Author: Mitodru Niyogi

# %%
import os
#import xml.etree.ElementTree as ET
import re
import itertools as it

import pandas as pd
import numpy as np


from src.preprocess import clean_text, preprocess_dataset
from src.preprocess import extract_article_title_xml, extract_all_articles, extract_bibliography_of_article, standardize_author_names
from src.preprocess import extract_ref_authors, extract_all_articles_authors, extract_all_cited_authors_of_paper
from src.preprocess import create_articles_authors_info_dict, create_dataset_csv, print_sort_alphabetic


# Define the directory path containing the A++ files
#dir_path = '/path/to/folder/containing/xml/files'
dir_path = '../test-articles/'

# %% [markdown]
# ### Extract a canonical alphabetical list of all the article titles.

# %%
titles = extract_all_articles(dir_path)

# %%
print_sort_alphabetic(titles, 'Title')
# Out:
# Title: 1 Adaptation options in agriculture to climate change: a typology
# Title: 2 Agrobacterial Transformation of Uninjured Plants
# Title: 3 An overview of the recent advances in spray-drying
# Title: 4 Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)
# Title: 5 Assessing the invasive potential of Eucalyptus globulus in Australia: quantification of wildling establishment from plantations
# Title: 6 Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests
# Title: 7 Climate change adaptation planning in remote, resource-dependent communities: an Arctic example
# Title: 8 Climate change, food security, and livelihoods in sub-Saharan Africa
# Title: 9 Community-based vulnerability assessment of Tuktoyaktuk, NWT, Canada to environmental and socio-economic changes
# Title: 10 Die Wirkung von Polymerzusätzen auf die Turbulenzstruktur in der ebenen Mischungsschicht zweier Ströme
# Title: 11 Editorial: Corporate Social Responsibility in Latin America
# Title: 12 Effects of climate change on Canada’s Pacific marine ecosystems: a summary of scientific knowledge
# Title: 13 Efflux Ratio Cannot Assess P-Glycoprotein-Mediated Attenuation of Absorptive Transport: Asymmetric Effect of P-Glycoprotein on Absorptive and Secretory Transport Across Caco-2 Cell Monolayers
# Title: 14 Enhancement of protein structure-forming properties in liquid foams by spray drying
# Title: 15 Enkele opmerkingen over groeimodellen
# Title: 16 Farm-Level Adaptation to Climatic Variability and Change: Crop Diversification in the Canadian Prairies
# Title: 17 Field dependence of magnetic ordering in the frustrated XY magnet Cs2CoCl4
# Title: 18 Fingering instability in non-Newtonian fluids during squeeze flow in a Hele-Shaw cell
# Title: 19 First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation
# Title: 20 Functional Expression and Localization of P-glycoprotein in the Central Nervous System: Relevance to the Pathogenesis and Treatment of Neurological Disorders
# Title: 21 Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy
# Title: 22 Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy
# Title: 23 History and nomenclature of the Conocardioidea (Mollusca: Rostroconchia)
# Title: 24 Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation
# Title: 25 Involvement of P-Glycoprotein in the Transport of Saquinavir and Indinavir in Rat Brain Microvessel Endothelial and Microglia Cell Lines
# Title: 26 Isolation and Characterization of Caco-2 Subclones Expressing High Levels of Multidrug Resistance Protein Efflux Transporter
# Title: 27 Marcia Karp, Paul Holmes & Kate Bradshaw Tauvon (Ed.): The Handbook of Psychodrama. Preface by Zerka T. Moreno
# Title: 28 Motivering en Betekenis van de Economische Hervorming in de Sowjet-Unie
# Title: 29 Multi-intersection Traffic Light Control with blocking
# Title: 30 New representations for (max,+) automata with applications to performance evaluation and control of discrete event systems
# Title: 31 Nomina dubia der Hippocardioidea (Mollusca; Rostroconchia)
# Title: 32 Oligocene to Middle Miocene basin development in the Vélez Rubio Corridor – Espuña (Internal-External Zone Boundary; Eastern Betic Cordilleras, SE Spain)
# Title: 33 On the V-states for the Generalized Quasi-Geostrophic Equations
# Title: 34 Ontvangen publikaties
# Title: 35 Over de beheersbaarheid van de geldhoeveelheid in Nederland
# Title: 36 Prediction of hip contact forces and muscle activations during walking at different speeds
# Title: 37 Protein apparatus for horizontal transfer of agrobacterial T-DNA to eukaryotic cells
# Title: 38 Recent climate change in the Prince Edward County winegrowing region, Ontario, Canada: implications for adaptation in a fledgling wine industry
# Title: 39 Statistic approach on taphonomic phenomena in shells ofGlycymeris glycymeris (Bivalvia: Glycymerididae) and its significance in the fossil record
# Title: 40 TNF levels in severe malaria treated by exchange transfusion (letter in reply to Doctor Smit et al.)
# Title: 41 Taxonomie und Systematik der HippocardioideaPojeta & Runnegar, 1976 [n. superfam.] (Mollusca; Rostroconchia)
# Title: 42 Teranota n. gen. (Bivalvia; Anomalodesmata) aus dem Mittel-Devon (Givetium) des Rheinischen Schiefergebirges
# Title: 43 The Complexities of Hepatic Drug Transport: Current Knowledge and Emerging Concepts
# Title: 44 The influence of interfaces and water uptake on the dielectric response of epoxy-cubic boron nitride composites
# Title: 45 To Control Or Not To Control? The Need To Control Some Alien Species, The Effectiveness Of Legislation And Possible Future Developments In The Law
# Title: 46 Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada
# Title: 47 Uit de Economist van 1884
# Title: 48 Uit de Economist van 1884
# Title: 49 Well-being and environmental change in the arctic: a synthesis of selected research from Canada’s International Polar Year program
# Title: 50 Zum Impuls-, Wärme- und Stoffaustausch in turbulenten Strömungen reagierender Binärgemische

# %% [markdown]
# ## Extract a canonical alphabetic list of all articles authors.

# %%
authors = extract_all_articles_authors(dir_path)

# %%
print_sort_alphabetic(authors, 'Author')

# %% [markdown]
# ## Extract a canonical alphabetical list of all the authors of cited articles.

# %%
# returns list of list of citations
# every index refers to the paper and its index refers to list of citations
#and its index refers to list of authors
ref_authors_all = extract_ref_authors(dir_path)

# %%
# aull cited authors for each artcile
papers_bib = extract_all_cited_authors_of_paper(ref_authors_all)

# %%
# sorted consolidated list of reference authors
consolidated_all_ref_authors_sorted = sorted(list(it.chain.from_iterable(papers_bib)))

# %%
# printing 
consolidated_all_ref_authors_sorted

# %% [markdown]
# ### Disambiguating authors by grouping

# %% [markdown]
# Disambiguating authors by extracting more information about the author. As we already saw that there are many authors with the same name. Here, I have created a dictionary with author name as key with list of publications, affiliations, journal subject, article id, article title, journal title as list of tuples to disambiguate authors with the same name.

# %%
# disambiguating authors by grouping 
authors_dict = create_articles_authors_info_dict(dir_path)

# %%
print(json.dumps(authors_dict, indent=4, ensure_ascii=False))
# Out:
# {
#     "Patrick T. Ronaldson": [
#         [
#             "10.1023/B:PHAM.0000026433.27773.47",
#             "Involvement of P-Glycoprotein in the Transport of Saquinavir and Indinavir in Rat Brain Microvessel Endothelial and Microglia Cell Lines",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Sciences, Leslie Dan Faculty of Pharmacy, University of Toronto"
#         ]
#     ],
#     "Gloria Lee": [
#         [
#             "10.1023/B:PHAM.0000026433.27773.47",
#             "Involvement of P-Glycoprotein in the Transport of Saquinavir and Indinavir in Rat Brain Microvessel Endothelial and Microglia Cell Lines",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Sciences, Leslie Dan Faculty of Pharmacy, University of Toronto"
#         ],
#         [
#             "10.1023/B:PHAM.0000036905.82914.8e",
#             "Functional Expression and Localization of P-glycoprotein in the Central Nervous System: Relevance to the Pathogenesis and Treatment of Neurological Disorders",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Laboratoire de Biophysique des Matériaux Alimentaires, UMR 1211 (AgroParisTech, CNAM, INRA)"
#         ]
#     ],
#     "Shannon Dallas": [
#         [
#             "10.1023/B:PHAM.0000026433.27773.47",
#             "Involvement of P-Glycoprotein in the Transport of Saquinavir and Indinavir in Rat Brain Microvessel Endothelial and Microglia Cell Lines",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Sciences, Leslie Dan Faculty of Pharmacy, University of Toronto"
#         ]
#     ],
#     "Reina Bendayan": [
#         [
#             "10.1023/B:PHAM.0000026433.27773.47",
#             "Involvement of P-Glycoprotein in the Transport of Saquinavir and Indinavir in Rat Brain Microvessel Endothelial and Microglia Cell Lines",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Sciences, Leslie Dan Faculty of Pharmacy, University of Toronto"
#         ],
#         [
#             "10.1023/B:PHAM.0000036905.82914.8e",
#             "Functional Expression and Localization of P-glycoprotein in the Central Nervous System: Relevance to the Pathogenesis and Treatment of Neurological Disorders",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Laboratoire de Biophysique des Matériaux Alimentaires, UMR 1211 (AgroParisTech, CNAM, INRA)"
#         ]
#     ],
#     "Adam Lindgreen": [
#         [
#             "10.1007/s10551-010-0611-1",
#             "Editorial: Corporate Social Responsibility in Latin America",
#             "Journal of Business Ethics",
#             "Philosophy",
#             "Business School, University of Birmingham"
#         ]
#     ],
#     "José-Rodrigo Córdoba": [
#         [
#             "10.1007/s10551-010-0611-1",
#             "Editorial: Corporate Social Responsibility in Latin America",
#             "Journal of Business Ethics",
#             "Philosophy",
#             "School of Management, Royal Holloway, University of London"
#         ]
#     ],
#     "Nicole S. Rogalla": [
#         [
#             "10.1007/BF02987952",
#             "\n              ",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Abteilung Invertebraten-Paläontologie, Institut für Geologie und Paläontologie der Philipps-Universität Marburg"
#         ],
#         [
#             "10.1007/BF02990209",
#             "Taxonomie und Systematik der Hippocardioidea",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Abteilung Invertebraten-Paläontologie, Institut für Geologie und Paläontologie der Philipps-Universität Marburg"
#         ],
#         [
#             "10.1007/BF02990183",
#             "Statistic approach on taphonomic phenomena in shells of",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "ABB Corporate Research"
#         ],
#         [
#             "10.1007/BF03009228",
#             "History and nomenclature of the Conocardioidea (Mollusca: Rostroconchia)",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Moskou"
#         ],
#         [
#             "10.1007/BF02988379",
#             "Nomina dubia der Hippocardioidea (Mollusca; Rostroconchia)",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Community of Paulatuk"
#         ]
#     ],
#     "Michael R. W. Amler": [
#         [
#             "10.1007/BF02987952",
#             "\n              ",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Abteilung Invertebraten-Paläontologie, Institut für Geologie und Paläontologie der Philipps-Universität Marburg"
#         ],
#         [
#             "10.1007/BF02990209",
#             "Taxonomie und Systematik der Hippocardioidea",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Abteilung Invertebraten-Paläontologie, Institut für Geologie und Paläontologie der Philipps-Universität Marburg"
#         ],
#         [
#             "10.1007/BF02990183",
#             "Statistic approach on taphonomic phenomena in shells of",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "ABB Corporate Research"
#         ],
#         [
#             "10.1007/BF03009228",
#             "History and nomenclature of the Conocardioidea (Mollusca: Rostroconchia)",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Moskou"
#         ],
#         [
#             "10.1007/BF02988379",
#             "Nomina dubia der Hippocardioidea (Mollusca; Rostroconchia)",
#             "Paläontologische Zeitschrift",
#             "Earth Sciences",
#             "Community of Paulatuk"
#         ]
#     ],
#     "Ben Bradshaw": [
#         [
#             "10.1007/s10584-004-0710-z",
#             "Farm-Level Adaptation to Climatic Variability and Change: Crop Diversification in the Canadian Prairies",
#             "Climatic Change",
#             "Geosciences",
#             "Department of Geography, Simon Fraser University"
#         ]
#     ],
#     "Holly Dolan": [
#         [
#             "10.1007/s10584-004-0710-z",
#             "Farm-Level Adaptation to Climatic Variability and Change: Crop Diversification in the Canadian Prairies",
#             "Climatic Change",
#             "Geosciences",
#             "Department of Geography, Simon Fraser University"
#         ]
#     ],
#     "Barry Smit": [
#         [
#             "10.1007/s10584-004-0710-z",
#             "Farm-Level Adaptation to Climatic Variability and Change: Crop Diversification in the Canadian Prairies",
#             "Climatic Change",
#             "Geosciences",
#             "Department of Geography, Simon Fraser University"
#         ],
#         [
#             "10.1007/s10113-012-0299-0",
#             "Community-based vulnerability assessment of Tuktoyaktuk, NWT, Canada to environmental and socio-economic changes",
#             "Regional Environmental Change",
#             "Environment",
#             "University of Guelph"
#         ],
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "Community of Ulukhaktok"
#         ],
#         [
#             "10.1007/s10113-015-0761-x",
#             "Climate change, food security, and livelihoods in sub-Saharan Africa",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, University of Guelph"
#         ],
#         [
#             "10.1007/s10113-013-0555-y",
#             "Recent climate change in the Prince Edward County winegrowing region, Ontario, Canada: implications for adaptation in a fledgling wine industry",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, University of Guelph"
#         ],
#         [
#             "10.1023/A:1015862228270",
#             "Adaptation options in agriculture to climate change: a typology",
#             "Mitigation and Adaptation Strategies for Global Change",
#             "Geosciences",
#             "Indigenous Environmental Studies Program, Trent University"
#         ],
#         [
#             "10.1007/s13280-014-0493-z",
#             "Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests",
#             "AMBIO",
#             "Environment",
#             "University of Prince Edward Island"
#         ]
#     ],
#     "Mark Andrachuk": [
#         [
#             "10.1007/s10113-012-0299-0",
#             "Community-based vulnerability assessment of Tuktoyaktuk, NWT, Canada to environmental and socio-economic changes",
#             "Regional Environmental Change",
#             "Environment",
#             "University of Guelph"
#         ]
#     ],
#     "Bridget Martin": [
#         [
#             "10.1007/s10991-006-9010-1",
#             "To Control Or Not To Control? The Need To Control Some Alien Species, The Effectiveness Of Legislation And Possible Future Developments In The Law",
#             "Liverpool Law Review",
#             "Law",
#             "Lancashire Law School, University of Central Lancashire"
#         ]
#     ],
#     "R. Scharf": [
#         [
#             "10.1007/BF01332608",
#             "Die Wirkung von Polymerzusätzen auf die Turbulenzstruktur in der ebenen Mischungsschicht zweier Ströme",
#             "Rheologica Acta",
#             "Physics",
#             "Lehrstuhl für Strömungsmechanik, Abteilung Chemietechnik der Universität Dortmund"
#         ]
#     ],
#     "A. Ghani": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ]
#     ],
#     "P. P. H. M. Delnoy": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ],
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "A. R. Ramdat Misier": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ],
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "J. J. J. Smit": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ],
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "A. Adiyaman": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ],
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "J. P. Ottervanger": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ]
#     ],
#     "A. Elvan": [
#         [
#             "10.1007/s12471-014-0556-6",
#             "Incidence of lead dislodgement, malfunction and perforation during the first year following device implantation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Hospital"
#         ],
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "P. Gal": [
#         [
#             "10.1007/s12471-014-0624-y",
#             "First Dutch experience with the endoscopic laser balloon ablation system for the treatment of atrial fibrillation",
#             "Netherlands Heart Journal",
#             "Medicine & Public Health",
#             "Department of Cardiology, Isala Klinieken"
#         ]
#     ],
#     "Anita Brandstätter": [
#         [
#             "10.1007/s00414-006-0114-x",
#             "Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)",
#             "International Journal of Legal Medicine",
#             "Medicine & Public Health",
#             "Institute of Legal Medicine, Innsbruck Medical University"
#         ]
#     ],
#     "Rachel Klein": [
#         [
#             "10.1007/s00414-006-0114-x",
#             "Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)",
#             "International Journal of Legal Medicine",
#             "Medicine & Public Health",
#             "Institute of Legal Medicine, University Clinics Ulm"
#         ]
#     ],
#     "Nina Duftner": [
#         [
#             "10.1007/s00414-006-0114-x",
#             "Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)",
#             "International Journal of Legal Medicine",
#             "Medicine & Public Health",
#             "Institute of Legal Medicine, Innsbruck Medical University"
#         ]
#     ],
#     "Peter Wiegand": [
#         [
#             "10.1007/s00414-006-0114-x",
#             "Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)",
#             "International Journal of Legal Medicine",
#             "Medicine & Public Health",
#             "Institute of Legal Medicine, University Clinics Ulm"
#         ]
#     ],
#     "Walther Parson": [
#         [
#             "10.1007/s00414-006-0114-x",
#             "Application of a quasi-median network analysis for the visualization of character conflicts to a population sample of mitochondrial DNA control region sequences from southern Germany (Ulm)",
#             "International Journal of Legal Medicine",
#             "Medicine & Public Health",
#             "Institute of Legal Medicine, Innsbruck Medical University"
#         ]
#     ],
#     "Dr. F. Salord": [
#         [
#             "10.1007/BF01709892",
#             "TNF levels in severe malaria treated by exchange transfusion (letter in reply to Doctor Smit et al.)",
#             "Intensive Care Medicine",
#             "Medicine & Public Health",
#             "Hôpital de la Croix-Rousse"
#         ]
#     ],
#     "I. A. Tsekmes": [
#         [
#             "10.1007/s10853-015-8940-1",
#             "The influence of interfaces and water uptake on the dielectric response of epoxy-cubic boron nitride composites",
#             "Journal of Materials Science",
#             "Material Science",
#             "Department of Electrical Sustainable Energy, TU Delft"
#         ]
#     ],
#     "P. H. F. Morshuis": [
#         [
#             "10.1007/s10853-015-8940-1",
#             "The influence of interfaces and water uptake on the dielectric response of epoxy-cubic boron nitride composites",
#             "Journal of Materials Science",
#             "Material Science",
#             "Department of Electrical Sustainable Energy, TU Delft"
#         ]
#     ],
#     "J. J. Smit": [
#         [
#             "10.1007/s10853-015-8940-1",
#             "The influence of interfaces and water uptake on the dielectric response of epoxy-cubic boron nitride composites",
#             "Journal of Materials Science",
#             "Material Science",
#             "Department of Electrical Sustainable Energy, TU Delft"
#         ]
#     ],
#     "R. Kochetov": [
#         [
#             "10.1007/s10853-015-8940-1",
#             "The influence of interfaces and water uptake on the dielectric response of epoxy-cubic boron nitride composites",
#             "Journal of Materials Science",
#             "Material Science",
#             "ABB Corporate Research"
#         ]
#     ],
#     "T. Geel": [
#         [
#             "10.1023/A:1003438421905",
#             "Oligocene to Middle Miocene basin development in the Vélez Rubio Corridor – Espuña (Internal-External Zone Boundary; Eastern Betic Cordilleras, SE Spain)",
#             "Geologie en Mijnbouw",
#             "Geosciences",
#             "Faculty of Earth Sciences, Vrije Universiteit, De Boelelaan 1085"
#         ]
#     ],
#     "Th.B. Roep": [
#         [
#             "10.1023/A:1003438421905",
#             "Oligocene to Middle Miocene basin development in the Vélez Rubio Corridor – Espuña (Internal-External Zone Boundary; Eastern Betic Cordilleras, SE Spain)",
#             "Geologie en Mijnbouw",
#             "Geosciences",
#             "Faculty of Earth Sciences, Vrije Universiteit, De Boelelaan 1085"
#         ]
#     ],
#     "M. I. Chumakov": [
#         [
#             "10.1023/A:1020921814222",
#             "Agrobacterial Transformation of Uninjured Plants",
#             "Russian Journal of Plant Physiology",
#             "Life Sciences",
#             "Institute of Biochemistry and Physiology of Plants and Microorganisms, Russian Academy of Sciences"
#         ],
#         [
#             "10.1134/S000629791312002X",
#             "Protein apparatus for horizontal transfer of agrobacterial T-DNA to eukaryotic cells",
#             "Biochemistry (Moscow)",
#             "Life Sciences",
#             "IRMAR, Université de Rennes 1"
#         ]
#     ],
#     "I. V. Kurbanova": [
#         [
#             "10.1023/A:1020921814222",
#             "Agrobacterial Transformation of Uninjured Plants",
#             "Russian Journal of Plant Physiology",
#             "Life Sciences",
#             "Institute of Biochemistry and Physiology of Plants and Microorganisms, Russian Academy of Sciences"
#         ]
#     ],
#     "G. K. Solovova": [
#         [
#             "10.1023/A:1020921814222",
#             "Agrobacterial Transformation of Uninjured Plants",
#             "Russian Journal of Plant Physiology",
#             "Life Sciences",
#             "Institute of Biochemistry and Physiology of Plants and Microorganisms, Russian Academy of Sciences"
#         ]
#     ],
#     "Prof. Dr.-Ing. M. Jischa": [
#         [
#             "10.1007/BF01003576",
#             "Zum Impuls-, Wärme- und Stoffaustausch in turbulenten Strömungen reagierender Binärgemische",
#             "Wärme - und Stoffübertragung",
#             "Physics",
#             "Fachbereich Maschinentechnik der Universität Essen-Gesamthochschule"
#         ]
#     ],
#     "Joost J Smit": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Immunotoxicology group, Institute for Risk Assessment Sciences, Utrecht University"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Maarten T Pennings": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Utrecht Centre for Food Allergy"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Karina Willemsen": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Immunotoxicology group, Institute for Risk Assessment Sciences, Utrecht University"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Manon van Roest": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Immunotoxicology group, Institute for Risk Assessment Sciences, Utrecht University"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Els van Hoffen": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Utrecht University Medical Center"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Raymond H Pieters": [
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             "Immunotoxicology group, Institute for Risk Assessment Sciences, Utrecht University"
#         ],
#         [
#             "10.1186/s13601-015-0056-9",
#             "Heterogeneous responses and cross reactivity between the major peanut allergens Ara h 1, 2,3 and 6 in a mouse model for peanut allergy",
#             "Clinical and Translational Allergy",
#             "Medicine & Public Health",
#             null
#         ]
#     ],
#     "Tristan Pearce": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "University of Guelph"
#         ],
#         [
#             "10.1007/s10113-012-0297-2",
#             "Climate change adaptation planning in remote, resource-dependent communities: an Arctic example",
#             "Regional Environmental Change",
#             "Environment",
#             "Münster"
#         ]
#     ],
#     "Harold Wright": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "Community of Ulukhaktok"
#         ]
#     ],
#     "Roland Notaina": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "Community of Ulukhaktok"
#         ]
#     ],
#     "Adam Kudlak": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "Community of Ulukhaktok"
#         ]
#     ],
#     "James Ford": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "McGill University"
#         ]
#     ],
#     "Christopher Furgal": [
#         [
#             "10.1007/s10745-011-9403-1",
#             "Transmission of Environmental Knowledge and Land Skills among Inuit Men in Ulukhaktok, Northwest Territories, Canada",
#             "Human Ecology",
#             "Social Sciences, general",
#             "Trent University"
#         ]
#     ],
#     "Matthew D. Troutman": [
#         [
#             "10.1023/A:1025049014674",
#             "Efflux Ratio Cannot Assess P-Glycoprotein-Mediated Attenuation of Absorptive Transport: Asymmetric Effect of P-Glycoprotein on Absorptive and Secretory Transport Across Caco-2 Cell Monolayers",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Division of Drug Delivery and Disposition, School of Pharmacy, the University of North Carolina at Chapel Hill"
#         ]
#     ],
#     "Dhiren R. Thakker": [
#         [
#             "10.1023/A:1025049014674",
#             "Efflux Ratio Cannot Assess P-Glycoprotein-Mediated Attenuation of Absorptive Transport: Asymmetric Effect of P-Glycoprotein on Absorptive and Secretory Transport Across Caco-2 Cell Monolayers",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Division of Drug Delivery and Disposition, School of Pharmacy, the University of North Carolina at Chapel Hill"
#         ]
#     ],
#     "Liette Connolly-Boutin": [
#         [
#             "10.1007/s10113-015-0761-x",
#             "Climate change, food security, and livelihoods in sub-Saharan Africa",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, University of Guelph"
#         ]
#     ],
#     "Matthew J. Larcombe": [
#         [
#             "10.1007/s10530-013-0492-1",
#             "Assessing the invasive potential of ",
#             "Biological Invasions",
#             "Life Sciences",
#             "School of Plant Science, University of Tasmania"
#         ]
#     ],
#     "Joaquim S. Silva": [
#         [
#             "10.1007/s10530-013-0492-1",
#             "Assessing the invasive potential of ",
#             "Biological Invasions",
#             "Life Sciences",
#             "Centre for Applied Ecology, Technical University of Lisbon"
#         ]
#     ],
#     "René E. Vaillancourt": [
#         [
#             "10.1007/s10530-013-0492-1",
#             "Assessing the invasive potential of ",
#             "Biological Invasions",
#             "Life Sciences",
#             "School of Plant Science, University of Tasmania"
#         ]
#     ],
#     "Brad M. Potts": [
#         [
#             "10.1007/s10530-013-0492-1",
#             "Assessing the invasive potential of ",
#             "Biological Invasions",
#             "Life Sciences",
#             "School of Plant Science, University of Tasmania"
#         ]
#     ],
#     "Rabah Boukra": [
#         [
#             "10.1007/s10626-013-0178-y",
#             "New representations for (max,+) automata with applications to performance evaluation and control of discrete event systems",
#             "Discrete Event Dynamic Systems",
#             "Mathematics",
#             "LUNAM Université, LISA"
#         ]
#     ],
#     "Sébastien Lahaye": [
#         [
#             "10.1007/s10626-013-0178-y",
#             "New representations for (max,+) automata with applications to performance evaluation and control of discrete event systems",
#             "Discrete Event Dynamic Systems",
#             "Mathematics",
#             "LUNAM Université, LISA"
#         ]
#     ],
#     "Jean-Louis Boimond": [
#         [
#             "10.1007/s10626-013-0178-y",
#             "New representations for (max,+) automata with applications to performance evaluation and control of discrete event systems",
#             "Discrete Event Dynamic Systems",
#             "Mathematics",
#             "LUNAM Université, LISA"
#         ]
#     ],
#     "Tara Holland": [
#         [
#             "10.1007/s10113-013-0555-y",
#             "Recent climate change in the Prince Edward County winegrowing region, Ontario, Canada: implications for adaptation in a fledgling wine industry",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, University of Guelph"
#         ]
#     ],
#     "Luca Modenese": [
#         [
#             "10.1007/s11044-011-9274-7",
#             "Prediction of hip contact forces and muscle activations during walking at different speeds",
#             "Multibody System Dynamics",
#             "Engineering",
#             "Structural Biomechanics, Dept. Civil and Environmental Engineering, Imperial College London"
#         ]
#     ],
#     "Andrew T. M. Phillips": [
#         [
#             "10.1007/s11044-011-9274-7",
#             "Prediction of hip contact forces and muscle activations during walking at different speeds",
#             "Multibody System Dynamics",
#             "Engineering",
#             "Structural Biomechanics, Dept. Civil and Environmental Engineering, Imperial College London"
#         ]
#     ],
#     "M. Kenzelmann": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Oxford Physics, Clarendon Laboratory, Parks Road, Oxford OX1 3PU, UK"
#         ]
#     ],
#     "R. Coldea": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Oak Ridge National Laboratory, Tennessee 37831, USA"
#         ]
#     ],
#     "D.A. Tennant": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Oxford Physics, Clarendon Laboratory, Parks Road, Oxford OX1 3PU, UK"
#         ]
#     ],
#     "D. Visser": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "ISIS Facility, Rutherford Appleton Laboratory, Oxon OX11 0QX, UK"
#         ]
#     ],
#     "M. Hofmann": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Hahn-Meitner-Institut, BENSC, 14109 Berlin, Germany"
#         ]
#     ],
#     "P. Smeibidl": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Hahn-Meitner-Institut, BENSC, 14109 Berlin, Germany"
#         ]
#     ],
#     "Z. Tylczynski": [
#         [
#             "10.1007/s003390201369",
#             "Field dependence of magnetic ordering in the frustrated ",
#             "Applied Physics A",
#             "Legacy",
#             "Institute of Physics, Adam Mickiewicz University, Umultowska 85, 61-614 Poznan, Poland"
#         ]
#     ],
#     "Brenda Parlee": [
#         [
#             "10.1007/s10584-012-0588-0",
#             "Well-being and environmental change in the arctic: a synthesis of selected research from Canada’s International Polar Year program",
#             "Climatic Change",
#             "Earth Sciences",
#             "Faculty of Native Studies, Faculty of Agricultural, Life and Environmental Sciences, University of Alberta"
#         ]
#     ],
#     "Chris Furgal": [
#         [
#             "10.1007/s10584-012-0588-0",
#             "Well-being and environmental change in the arctic: a synthesis of selected research from Canada’s International Polar Year program",
#             "Climatic Change",
#             "Earth Sciences",
#             "Indigenous Environmental Studies Program, Trent University"
#         ]
#     ],
#     "Mark W. Skinner": [
#         [
#             "10.1023/A:1015862228270",
#             "Adaptation options in agriculture to climate change: a typology",
#             "Mitigation and Adaptation Strategies for Global Change",
#             "Geosciences",
#             null
#         ]
#     ],
#     "Thomas A. Okey": [
#         [
#             "10.1007/s11160-014-9342-1",
#             "Effects of climate change on Canada’s Pacific marine ecosystems: a summary of scientific knowledge",
#             "Reviews in Fish Biology and Fisheries",
#             "Life Sciences",
#             "School of Environmental Studies, University of Victoria"
#         ]
#     ],
#     "Hussein M. Alidina": [
#         [
#             "10.1007/s11160-014-9342-1",
#             "Effects of climate change on Canada’s Pacific marine ecosystems: a summary of scientific knowledge",
#             "Reviews in Fish Biology and Fisheries",
#             "Life Sciences",
#             "WWF-Canada"
#         ]
#     ],
#     "Veronica Lo": [
#         [
#             "10.1007/s11160-014-9342-1",
#             "Effects of climate change on Canada’s Pacific marine ecosystems: a summary of scientific knowledge",
#             "Reviews in Fish Biology and Fisheries",
#             "Life Sciences",
#             "Canadian Parks and Wilderness Society"
#         ]
#     ],
#     "Sabine Jessen": [
#         [
#             "10.1007/s11160-014-9342-1",
#             "Effects of climate change on Canada’s Pacific marine ecosystems: a summary of scientific knowledge",
#             "Reviews in Fish Biology and Fisheries",
#             "Life Sciences",
#             "Canadian Parks and Wilderness Society"
#         ]
#     ],
#     "Priyamvada Chandra": [
#         [
#             "10.1023/B:PHAM.0000026420.79421.8f",
#             "The Complexities of Hepatic Drug Transport: Current Knowledge and Emerging Concepts",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Division of Drug Delivery and Disposition, University of North Carolina at Chapel Hill"
#         ]
#     ],
#     "Kim L. R. Brouwer": [
#         [
#             "10.1023/B:PHAM.0000026420.79421.8f",
#             "The Complexities of Hepatic Drug Transport: Current Knowledge and Emerging Concepts",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Division of Drug Delivery and Disposition, University of North Carolina at Chapel Hill"
#         ]
#     ],
#     "Prof. Dr. A. Heertje": [
#         [
#             "10.1007/BF02367222",
#             "Enkele opmerkingen over groeimodellen",
#             "De Economist",
#             "Economics / Management Science",
#             null
#         ]
#     ],
#     "M Dutta Choudhury": [
#         [
#             "10.1007/s12648-014-0606-3",
#             "Fingering instability in non-Newtonian fluids during squeeze flow in a Hele-Shaw cell",
#             "Indian Journal of Physics",
#             "Physics",
#             "Condensed Matter Physics Research Centre, Jadavpur University"
#         ]
#     ],
#     "S Tarafdar": [
#         [
#             "10.1007/s12648-014-0606-3",
#             "Fingering instability in non-Newtonian fluids during squeeze flow in a Hele-Shaw cell",
#             "Indian Journal of Physics",
#             "Physics",
#             "Condensed Matter Physics Research Centre, Jadavpur University"
#         ]
#     ],
#     "Arun S. Mujumdar": [
#         [
#             "10.1051/dst/2010015",
#             "An overview of the recent advances in spray-drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "National University of Singapore"
#         ]
#     ],
#     "Li-Xin Huang": [
#         [
#             "10.1051/dst/2010015",
#             "An overview of the recent advances in spray-drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Institute of Chemical Industries of Forestry Products"
#         ]
#     ],
#     "Xiao Dong Chen": [
#         [
#             "10.1051/dst/2010015",
#             "An overview of the recent advances in spray-drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Department of Chemical Engineering, Monash University"
#         ]
#     ],
#     "H. Carolyn Peach Brown": [
#         [
#             "10.1007/s13280-014-0493-z",
#             "Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests",
#             "AMBIO",
#             "Environment",
#             "University of Prince Edward Island"
#         ]
#     ],
#     "Olufunso A. Somorin": [
#         [
#             "10.1007/s13280-014-0493-z",
#             "Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests",
#             "AMBIO",
#             "Environment",
#             "Forest and Nature Conservation Policy Group, Wageningen University"
#         ]
#     ],
#     "Denis J. Sonwa": [
#         [
#             "10.1007/s13280-014-0493-z",
#             "Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests",
#             "AMBIO",
#             "Environment",
#             "Center for International Forestry Research (CIFOR), Central African Regional Office"
#         ]
#     ],
#     "Johnson Ndi Nkem": [
#         [
#             "10.1007/s13280-014-0493-z",
#             "Climate Change and Forest Communities: Prospects for Building Institutional Adaptive Capacity in the Congo Basin Forests",
#             "AMBIO",
#             "Environment",
#             "Climate Change Adaptation and Development Programme, United Nations Development Programme (UNDP)"
#         ]
#     ],
#     "Prof. Dr. P. Korteweg": [
#         [
#             "10.1007/BF02367128",
#             "Over de beheersbaarheid van de geldhoeveelheid in Nederland",
#             "De Economist",
#             "Economics / Management Science",
#             null
#         ]
#     ],
#     "Clémence Bernard": [
#         [
#             "10.1051/dst:2007017",
#             "Enhancement of protein structure-forming properties in liquid foams by spray drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Laboratoire de Biophysique des Matériaux Alimentaires, UMR 1211 (AgroParisTech, CNAM, INRA)"
#         ]
#     ],
#     "Bertrand Broyart": [
#         [
#             "10.1051/dst:2007017",
#             "Enhancement of protein structure-forming properties in liquid foams by spray drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Laboratoire de Génie des Procédés, UMR 1145 (AgroParisTech, CEMAGREF, INRA)"
#         ]
#     ],
#     "Jean Vasseur": [
#         [
#             "10.1051/dst:2007017",
#             "Enhancement of protein structure-forming properties in liquid foams by spray drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Laboratoire de Génie des Procédés, UMR 1145 (AgroParisTech, CEMAGREF, INRA)"
#         ]
#     ],
#     "Pablo Granda": [
#         [
#             "10.1051/dst:2007017",
#             "Enhancement of protein structure-forming properties in liquid foams by spray drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Laboratoire de Biophysique des Matériaux Alimentaires, UMR 1211 (AgroParisTech, CNAM, INRA)"
#         ]
#     ],
#     "Perla Relkin": [
#         [
#             "10.1051/dst:2007017",
#             "Enhancement of protein structure-forming properties in liquid foams by spray drying",
#             "Dairy Science & Technology",
#             "Chemistry",
#             "Laboratoire de Biophysique des Matériaux Alimentaires, UMR 1211 (AgroParisTech, CNAM, INRA)"
#         ]
#     ],
#     "Zineb Hassainia": [
#         [
#             "10.1007/s00220-015-2300-5",
#             "On the V-states for the Generalized Quasi-Geostrophic Equations",
#             "Communications in Mathematical Physics",
#             "Physics",
#             "IRMAR, Université de Rennes 1"
#         ]
#     ],
#     "Taoufik Hmidi": [
#         [
#             "10.1007/s00220-015-2300-5",
#             "On the V-states for the Generalized Quasi-Geostrophic Equations",
#             "Communications in Mathematical Physics",
#             "Physics",
#             "IRMAR, Université de Rennes 1"
#         ]
#     ],
#     "Kazutoshi Horie": [
#         [
#             "10.1023/A:1022359300826",
#             "Isolation and Characterization of Caco-2 Subclones Expressing High Levels of Multidrug Resistance Protein Efflux Transporter",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Chemistry, The University of Kansas"
#         ]
#     ],
#     "Fuxing Tang": [
#         [
#             "10.1023/A:1022359300826",
#             "Isolation and Characterization of Caco-2 Subclones Expressing High Levels of Multidrug Resistance Protein Efflux Transporter",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Chemistry, The University of Kansas"
#         ]
#     ],
#     "Ronald T. Borchardt": [
#         [
#             "10.1023/A:1022359300826",
#             "Isolation and Characterization of Caco-2 Subclones Expressing High Levels of Multidrug Resistance Protein Efflux Transporter",
#             "Pharmaceutical Research",
#             "Biomedicine",
#             "Department of Pharmaceutical Chemistry, The University of Kansas"
#         ]
#     ],
#     "Prof. I. Faminski": [
#         [
#             "10.1007/BF02182493",
#             "Motivering en Betekenis van de Economische Hervorming in de Sowjet-Unie",
#             "De Economist",
#             "Economics / Management Science",
#             "Moskou"
#         ]
#     ],
#     "Ferdinand Buer": [
#         [
#             "10.1007/s11620-003-0038-0",
#             "Marcia Karp, Paul Holmes & Kate Bradshaw Tauvon (Ed.): The Handbook of Psychodrama. Preface by Zerka T. Moreno",
#             "Zeitschrift für Psychodrama und Soziometrie",
#             "Social Sciences, general",
#             "Münster"
#         ]
#     ],
#     "James D. Ford": [
#         [
#             "10.1007/s10113-012-0297-2",
#             "Climate change adaptation planning in remote, resource-dependent communities: an Arctic example",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, McGill University"
#         ]
#     ],
#     "Amanda Caron": [
#         [
#             "10.1007/s10113-012-0297-2",
#             "Climate change adaptation planning in remote, resource-dependent communities: an Arctic example",
#             "Regional Environmental Change",
#             "Environment",
#             "Department of Geography, McGill University"
#         ]
#     ],
#     "Bill Patrick Kudlak": [
#         [
#             "10.1007/s10113-012-0297-2",
#             "Climate change adaptation planning in remote, resource-dependent communities: an Arctic example",
#             "Regional Environmental Change",
#             "Environment",
#             "Community of Paulatuk"
#         ]
#     ],
#     "Yanfeng Geng": [
#         [
#             "10.1007/s10626-013-0176-0",
#             "Multi-intersection Traffic Light Control with blocking",
#             "Discrete Event Dynamic Systems",
#             "Mathematics",
#             "Division of Systems Engineering and Center for Information and Systems Engineering, Boston University"
#         ]
#     ],
#     "Christos G. Cassandras": [
#         [
#             "10.1007/s10626-013-0176-0",
#             "Multi-intersection Traffic Light Control with blocking",
#             "Discrete Event Dynamic Systems",
#             "Mathematics",
#             "Division of Systems Engineering and Center for Information and Systems Engineering, Boston University"
#         ]
#     ],
#     "D. Hartevelt": [
#         [
#             "10.1007/BF02380350",
#             "Uit de Economist van 1884",
#             "De Economist",
#             "Economics / Management Science",
#             null
#         ]
#     ]
# }

# %% [markdown]
# Here we can see that there are two persons Gloria Lee with different affiliations but in the same research field. There are 7 authors with the  name 'Barry Smit'

# %%
# creating csv file with authors information
create_dataset_csv(authors_dict, dir_path)

# %%
df = pd.read_csv(dir_path+'authors.csv')

# %%
df
# Out:
#                      Author                           ArticleID
# 0      Patrick T. Ronaldson  10.1023/B:PHAM.0000026433.27773.47  \
# 1                Gloria Lee  10.1023/B:PHAM.0000026433.27773.47
# 2                Gloria Lee  10.1023/B:PHAM.0000036905.82914.8e
# 3            Shannon Dallas  10.1023/B:PHAM.0000026433.27773.47
# 4            Reina Bendayan  10.1023/B:PHAM.0000026433.27773.47
# ..                      ...                                 ...
# 132            Amanda Caron           10.1007/s10113-012-0297-2
# 133     Bill Patrick Kudlak           10.1007/s10113-012-0297-2
# 134            Yanfeng Geng           10.1007/s10626-013-0176-0
# 135  Christos G. Cassandras           10.1007/s10626-013-0176-0
# 136            D. Hartevelt                  10.1007/BF02380350
#
#                                          Article Title
# 0    Involvement of P-Glycoprotein in the Transport...  \
# 1    Involvement of P-Glycoprotein in the Transport...
# 2    Functional Expression and Localization of P-gl...
# 3    Involvement of P-Glycoprotein in the Transport...
# 4    Involvement of P-Glycoprotein in the Transport...
# ..                                                 ...
# 132  Climate change adaptation planning in remote, ...
# 133  Climate change adaptation planning in remote, ...
# 134  Multi-intersection Traffic Light Control with ...
# 135  Multi-intersection Traffic Light Control with ...
# 136                          Uit de Economist van 1884
#
#                       Journal Title                 Journal Subject
# 0           Pharmaceutical Research                     Biomedicine  \
# 1           Pharmaceutical Research                     Biomedicine
# 2           Pharmaceutical Research                     Biomedicine
# 3           Pharmaceutical Research                     Biomedicine
# 4           Pharmaceutical Research                     Biomedicine
# ..                              ...                             ...
# 132   Regional Environmental Change                     Environment
# 133   Regional Environmental Change                     Environment
# 134  Discrete Event Dynamic Systems                     Mathematics
# 135  Discrete Event Dynamic Systems                     Mathematics
# 136                    De Economist  Economics / Management Science
#
#                                           Affiliations
# 0    Department of Pharmaceutical Sciences, Leslie ...
# 1    Department of Pharmaceutical Sciences, Leslie ...
# 2    Laboratoire de Biophysique des Matériaux Alime...
# 3    Department of Pharmaceutical Sciences, Leslie ...
# 4    Department of Pharmaceutical Sciences, Leslie ...
# ..                                                 ...
# 132         Department of Geography, McGill University
# 133                              Community of Paulatuk
# 134  Division of Systems Engineering and Center for...
# 135  Division of Systems Engineering and Center for...
# 136                                                NaN
#
# [137 rows x 6 columns]
